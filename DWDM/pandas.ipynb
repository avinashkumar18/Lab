# %% [markdown]
# <a href="https://colab.research.google.com/github/avinashkumar18/Lab/blob/main/DWDM/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://catalogue.data.gov.bc.ca/dataset/29af9a16-17a0-499d-a927-1fec62d18a20/resource/df9f563d-5242-4589-8c87-3ebc54cf1eab/download/bc-adult-education-institutions-data-sheet-july2020.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#                          Institution  ...                                               Link
# 0  Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 1  Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 2  Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 3               Capilano University   ...                     https://www.capilanou.ca/abe/
# 4               Capilano University   ...              http://www.capilanou.ca/sunshineabe/
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Institution       89 non-null     object
#  1   Campus_District   89 non-null     object
#  2   Institution_type  89 non-null     object
#  3   Ec_Dev_Region     85 non-null     object
#  4   City              89 non-null     object
#  5   Address           89 non-null     object
#  6   Postal_Code       88 non-null     object
#  7   Latitude          89 non-null     float64
#  8   Longitude         89 non-null     float64
#  9   Dept_Email        29 non-null     object
#  10  Dept_Phone        89 non-null     object
#  11  Link              89 non-null     object
# dtypes: float64(2), object(10)
# memory usage: 8.5+ KB

# %%
df.sort_values('Campus_District')
# Out:
#                              Institution  ...                                               Link
# 6      University of Fraser Valley (UFV)  ...                      https://www.ufv.ca/upgrading/
# 63       Surrey School's Adult Education  ...  https://www.surreyschools.ca/AdultEducation/Pa...
# 64         Richmond Continuing Education  ...    http://ce.sd38.bc.ca/adult-secondary-graduation
# 76  Continuing Education Centre Kamloops  ...                    http://continuinged.sd73.bc.ca/
# 80            Continuing Education Delta  ...  https://www.deltasd.bc.ca/programs/continuing-...
# ..                                   ...  ...                                                ...
# 28            North Island College (NIC)  ...     \nhttps://www.nic.bc.ca/programs/upgrading/ \n
# 31           Vancouver Community College  ...  \nhttp://www.vcc.ca/programscourses/program-ar...
# 29                       Langara College  ...         \nhttps://langara.ca/admissions/index.html
# ...

# %%
df.sort_values('Campus_District',ascending=False)
# Out:
#                              Institution  ...                                               Link
# 42      Thompson Rivers University (TRU)  ...  https://www.tru.ca/williamslake/programs/unive...
# 48                      Okanagan College  ...                      www.okanagan.bc.ca/upgrading
# 29                       Langara College  ...         \nhttps://langara.ca/admissions/index.html
# 31           Vancouver Community College  ...  \nhttp://www.vcc.ca/programscourses/program-ar...
# 28            North Island College (NIC)  ...     \nhttps://www.nic.bc.ca/programs/upgrading/ \n
# ..                                   ...  ...                                                ...
# 80            Continuing Education Delta  ...  https://www.deltasd.bc.ca/programs/continuing-...
# 76  Continuing Education Centre Kamloops  ...                    http://continuinged.sd73.bc.ca/
# 64         Richmond Continuing Education  ...    http://ce.sd38.bc.ca/adult-secondary-graduation
# ...

# %%
df.rename(columns = {'City':'Place'})
# Out:
#                                  Institution  ...                                               Link
# 0          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 1          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 2          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 3                       Capilano University   ...                     https://www.capilanou.ca/abe/
# 4                       Capilano University   ...              http://www.capilanou.ca/sunshineabe/
# ..                                       ...  ...                                                ...
# 84                     Adult Learning Centre  ...  https://newwestschools.ca/programs-services/ad...
# 85     Adult Education/ Distributed Learning  ...                  http://northwesttradescentre.com/
# ...

# %%
df.sort_index()
# Out:
#                                  Institution  ...                                               Link
# 0          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 1          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 2          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 3                       Capilano University   ...                     https://www.capilanou.ca/abe/
# 4                       Capilano University   ...              http://www.capilanou.ca/sunshineabe/
# ..                                       ...  ...                                                ...
# 84                     Adult Learning Centre  ...  https://newwestschools.ca/programs-services/ad...
# 85     Adult Education/ Distributed Learning  ...                  http://northwesttradescentre.com/
# ...

# %%
df.reset_index()
# Out:
#     index  ...                                               Link
# 0       0  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 1       1  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 2       2  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 3       3  ...                     https://www.capilanou.ca/abe/
# 4       4  ...              http://www.capilanou.ca/sunshineabe/
# ..    ...  ...                                                ...
# 84     84  ...  https://newwestschools.ca/programs-services/ad...
# 85     85  ...                  http://northwesttradescentre.com/
# 86     86  ...  http://go.vsb.bc.ca/schools/adulted/Pages/defa...
# 87     87  ...                    http://www.westshorecentre.com/
# 88     88  ...                      http://yl2.sd53.bc.ca/moodle/
#
# [89 rows x 13 columns]

# %%
df.drop(columns=['Postal_Code'])
# Out:
#                                  Institution  ...                                               Link
# 0          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 1          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 2          Vancouver Island University (VIU)  ...  https://www.viu.ca/programs/acp/high-school-eq...
# 3                       Capilano University   ...                     https://www.capilanou.ca/abe/
# 4                       Capilano University   ...              http://www.capilanou.ca/sunshineabe/
# ..                                       ...  ...                                                ...
# 84                     Adult Learning Centre  ...  https://newwestschools.ca/programs-services/ad...
# 85     Adult Education/ Distributed Learning  ...                  http://northwesttradescentre.com/
# ...

# %%
df['City'].value_counts()
# Out:
# Victoria           4
# Vancouver          4
# Kamloops           2
# North Vancouver    2
# Parksville         2
#                   ..
# Richmond           1
# Fort St. James     1
# Cranbrook          1
# Courtenay          1
# Hope               1
# Name: City, Length: 64, dtype: int64

# %%
df['City'].nunique()
# Out:
# 64

# %%
url = 'https://raw.githubusercontent.com/avinashkumar18/Lab/main/Deep%20Learning/Assignment%201/cancer%20dataset.csv'
data=pd.read_csv(url)

# %%
data.head()
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  target
# 0        17.99         10.38  ...                  0.11890       0
# 1        20.57         17.77  ...                  0.08902       0
# 2        19.69         21.25  ...                  0.08758       0
# 3        11.42         20.38  ...                  0.17300       0
# 4        20.29         14.34  ...                  0.07678       0
#
# [5 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
data['smoothness error'].sum()
# Out:
# 4.006316999999999

# %%
data['mean radius'].mean()
# Out:
# 14.127291739894563

# %%
  data['target'].unique()
# Out:
# array([0, 1])

# %%
data['target'].value_counts()
# Out:
# 1    357
# 0    212
# Name: target, dtype: int64

# %%
print(data['worst area'].min())
print(data['worst area'].max())
# Out:
# 185.2
# 4254.0

# %%
print(data['worst radius'].mean())
print(data['worst radius'].std())
# Out:
# 16.269189806678394
# 4.833241580469324
